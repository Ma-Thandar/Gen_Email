# %%
pip install langchain-groq
# Out:
# ...
#
# ...

# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(    
    temperature=0,
    groq_api_key='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',
    model_name='llama-3.1-70b-versatile'  
)
response = llm.invoke("the man who created exectric bulb")
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# PermissionDeniedError                     Traceback (most recent call last)
# Cell In[7], line 6
#       1 llm = ChatGroq(
#       2     temperature=0,
#       3     groq_api_key='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',
#       4     model_name='llama-3.1-70b-versatile'
#       5 )
# ----> 6 response = llm.invoke("the man who created exectric bulb")
#       7 print(response.content)
#
# File ~\anaconda3\envs\TDA_SImbolo\lib\site-packages\langchain_core\language_models\chat_models.py:286, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     275 def invoke(
#     276     self,
#     277     input: LanguageModelInput,
#    (...)
#     281     **kwargs: Any,
#     282 ) -> BaseMessage:
#     283     config = ensure_config(config)
#     284     return cast(
#     285         ChatGeneration,
# --> 286         self.generate_prompt(
# ...
